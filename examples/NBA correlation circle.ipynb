# %%
from PCACorrCircle import pca_correlation_graph
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('examples/NBA-data-With-Positions.csv').drop(['Unnamed: 0'],axis=1)
df_numeric = df.drop(['PosicAbbrev','Player','TEAM','+/-','03:00:00 PM','3PA'],axis=1)
X = df_numeric.values
X = (X - X.mean(axis=0))/X.std(axis=0)
df_numeric.head()
# Out:
#    AGE  GP   W   L   MIN  FGM   FGA   FG%   3P%  FTM  ...  REB  AST  TOV  STL  \
# 0   31  69  36  33  16.1  2.7   6.8  40.1  35.7  0.7  ...  1.5  2.6  1.2  0.4
# 1   20  78  32  46  23.9  3.5   7.4  47.3  29.6  1.7  ...  6.5  1.6  0.8  0.8
# 2   21  21  15   6   4.4  0.2   0.9  26.3  30.0  0.2  ...  0.7  0.1  0.2  0.3
# 3   25  52  18  34   9.3  1.0   2.8  36.6  28.1  0.3  ...  2.1  0.6  0.7  0.3
# 4   30  82  48  34  32.1  6.5  12.8  50.5  34.4  1.3  ...  7.3  3.2  1.3  0.8
#
#    BLK   PF  DD2  TD3   PTS    SALARY
# 0  0.1  1.9    0    0   7.1   2250000
# 1  0.7  2.0   12    0   9.2   4171680
# 2  0.0  0.5    0    0   0.9    525093
# 3  0.2  1.5    0    0   2.5   1938840
# 4  1.5  2.0   17    0  15.2  12000000
#
# [5 rows x 24 columns]

# %%
_ = PC.pca_correlation_graph(X,df_numeric.columns,figure_axis_size=14)
